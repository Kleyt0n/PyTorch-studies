# %% [markdown]
# # Chapter 2

# %%
import torch
from torchvision import models
from torchvision import transforms

# %%
dir(models)
# Out:
# ['AlexNet',
#  'DenseNet',
#  'GoogLeNet',
#  'GoogLeNetOutputs',
#  'Inception3',
#  'InceptionOutputs',
#  'MNASNet',
#  'MobileNetV2',
#  'MobileNetV3',
#  'ResNet',
#  'ShuffleNetV2',
#  'SqueezeNet',
#  'VGG',
#  '_GoogLeNetOutputs',
#  '_InceptionOutputs',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '_utils',
#  'alexnet',
#  'densenet',
#  'densenet121',
#  'densenet161',
#  'densenet169',
#  'densenet201',
#  'detection',
#  'googlenet',
#  'inception',
#  'inception_v3',
#  'mnasnet',
#  'mnasnet0_5',
#  'mnasnet0_75',
#  'mnasnet1_0',
#  'mnasnet1_3',
#  'mobilenet',
#  'mobilenet_v2',
#  'mobilenet_v3_large',
#  'mobilenet_v3_small',
#  'mobilenetv2',
#  'mobilenetv3',
#  'quantization',
#  'resnet',
#  'resnet101',
#  'resnet152',
#  'resnet18',
#  'resnet34',
#  'resnet50',
#  'resnext101_32x8d',
#  'resnext50_32x4d',
#  'segmentation',
#  'shufflenet_v2_x0_5',
# ...

# %%
# transforms allow us to define pipelines of basic preprocessing functions 

preprocess = transforms.Compose([
        transforms.Resize(256), # scale the input image tp 256x256
        transforms.CenterCrop(224), # crop the image to 224x224 around the center
        transforms.ToTensor(), # transform to a tensor
        transforms.Normalize( # normalize 
            mean = [0.485,0.456,0.406],
            std = [0.229,0.224,0.225]
        )
])

# %%
import numpy as np
import torch

np.random.seed(2)

T = 20
L = 1000
N = 100

x = np.empty((N, L), 'int64')
x[:] = np.array(range(L)) + np.random.randint(-4 * T, 4 * T, N).reshape(N, 1)
data = np.sin(x / 1.0 / T).astype('float64')
data
# Out:
# array([[ 0.10819513,  0.05837414,  0.00840725, ...,  0.50025202,
#          0.45635088,  0.4113091 ],
#        [-0.38941834, -0.34289781, -0.29552021, ..., -0.72805642,
#         -0.69288495, -0.65598164],
#        [-0.23924933, -0.28747801, -0.33498815, ...,  0.17301479,
#          0.12357312,  0.07382259],
#        ...,
#        [-0.24740396, -0.19866933, -0.14943813, ..., -0.61743871,
#         -0.57735251, -0.53582323],
#        [ 0.99749499,  0.99978376,  0.9995736 , ...,  0.88407805,
#          0.90633041,  0.92631742],
#        [-0.99749499, -0.99271299, -0.98544973, ..., -0.94118156,
#         -0.95689335, -0.97021341]])
